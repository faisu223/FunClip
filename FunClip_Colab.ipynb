# %% [markdown]
# # FunClip: One-Click Colab Notebook
#
# Welcome to FunClip on Google Colab! This notebook will set up and run the FunClip application for you.
#
# **Instructions:**
# 1.  Run the "Setup" cell. This will take a few minutes.
# 2.  Run the "Launch FunClip" cell.
# 3.  Click the public Gradio link that appears in the output to open the FunClip interface in a new tab.

# %%
# This cell will clone the repository, install all necessary dependencies, and download required assets.

import os

# Clone the repository
# !git clone https://github.com/alibaba-damo-academy/FunClip.git
# %cd FunClip

# Install Python dependencies
# !pip install -r requirements.txt

# Install imagemagick for subtitles
# !apt-get -y update && apt-get -y install --fix-missing ffmpeg imagemagick
# This next line is important for imagemagick policy on Colab
# !sed -i 's/none/read,write/g' /etc/ImageMagick-6/policy.xml

# Download font for subtitles
# !wget https://isv-data.oss-cn-hangzhou.aliyuncs.com/ics/MaaS/ClipVideo/STHeitiMedium.ttc -O font/STHeitiMedium.ttc

print("✅ Setup complete!")

# %% [markdown]
# ## 2. Launch FunClip
#
# This cell will start the FunClip Gradio application. Once it's running, you'll see a public URL. Click on it to start clipping!
#
# **Note on API Keys:** You can enter your API keys for services like Gemini or OpenAI directly in the FunClip user interface.

# %%
# This will start the Gradio web interface.
# !python funclip/launch.py --share True
